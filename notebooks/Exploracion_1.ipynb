# %% [markdown]
# # Primera exploración de los datos de calidad de aire

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import sys
import os
import glob
sys.path.append('../src')
import cargadata as cdat
import datetime
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Carga de archivos

# %%
contenido = os.listdir('../data/')
contenido
# Out:
# ['a2020',
#  'a2021',
#  'c2020',
#  'c2021',
#  'calidad_aire_estaciones.csv',
#  'calidad_aire_estaciones.json',
#  'df_total.csv',
#  'estaciones.csv',
#  'estaciones_comu.xlsx',
#  'informacion_estaciones_red_calidad_aire__ayunta.csv',
#  'informacion_estaciones_red_calidad_aire__ayunta.geo',
#  'meteo20__ayunta.csv',
#  'meteo21_ayunta.csv',
#  'spacmsuelossoiltaxonomy2000.areas_calidad_aire.json',
#  'zonas_calidad_aire',
#  '~$estaciones_comu.xlsx']

# %%
con_a2021 = os.listdir('../data/a2021')
con_a2021;

# %%
df_c_20 = cdat.df_from_csvs('../data/c2020')
df_c_21 = cdat.df_from_csvs('../data/c2021')
df_a_20 = cdat.df_from_csvs('../data/a2020')
df_a_21 = cdat.df_from_csvs('../data/a2020')

# %%
df_c_20.sample()
# Out:
#       provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  \
# 4866         28         92         5        82  28092005_82_89  2020    1
#
#       dia    h01 v01  ...    h20 v20    h21 v21    h22 v22    h23 v23    h24  \
# 4866   29  241.0   V  ...  228.0   V  226.0   V  231.0   V  213.0   V  214.0
#
#      v24
# 4866   V
#
# [1 rows x 56 columns]

# %%
df_c_21.sample()
# Out:
#        provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  \
# 31025         28         65        14        82  28065014_82_89  2021    7
#
#        dia    h01 v01  ...    h20 v20    h21 v21    h22 v22    h23 v23    h24  \
# 31025    4  238.0   V  ...  204.0   V  245.0   V  262.0   V  275.0   V  270.0
#
#       v24
# 31025   V
#
# [1 rows x 56 columns]

# %%
df_a_20.sample()
# Out:
#        PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 14872         28         79        17         8   28079017_8_8  2020    1
#
#        DIA   H01 V01  ...   H20 V20   H21 V21   H22 V22   H23 V23   H24 V24
# 14872   22  10.0   V  ...  30.0   V  28.0   V  30.0   V  25.0   V  21.0   V
#
# [1 rows x 56 columns]

# %%
df_a_21.sample()
# Out:
#        PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 50705         28         79        59         7   28079059_7_8  2020   10
#
#        DIA  H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 50705   22  1.0   V  ...  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
#
# [1 rows x 56 columns]

# %%
columns_names = ['provincia', 'municipio', 'estacion', 'magnitud', 'punto_muestreo',
       'year', 'month', 'day', 'h01', 'v01', 'h02', 'v02', 'h03', 'v03', 'h04',
       'v04', 'h05', 'v05', 'h06', 'v06', 'h07', 'v07', 'h08', 'v08', 'h09',
       'v09', 'h10', 'v10', 'h11', 'v11', 'h12', 'v12', 'h13', 'v13', 'h14',
       'v14', 'h15', 'v15', 'h16', 'v16', 'h17', 'v17', 'h18', 'v18', 'h19',
       'v19', 'h20', 'v20', 'h21', 'v21', 'h22', 'v22', 'h23', 'v23', 'h24',
       'v24']

# %%
df_c_20.set_axis(columns_names, axis='columns', inplace=True)
df_c_21.set_axis(columns_names, axis='columns', inplace=True)
df_a_20.set_axis(columns_names, axis='columns', inplace=True)
df_a_21.set_axis(columns_names, axis='columns', inplace=True)

# %% [markdown]
# Las columnas son las mismas. puedo unir todos en uno.

# %%
li_total = [df_c_20, df_c_21, df_a_20, df_a_21]

# %%
df_total = pd.concat(li_total, axis=0, ignore_index=False)

# %%
df_total.head(30)
# Out:
#     provincia  municipio  estacion  magnitud  punto_muestreo  year  month  \
# 0          28        102         1        81  28102001_81_89  2020      1
# 1          28        102         1        82  28102001_82_89  2020      1
# 2          28        102         1        83  28102001_83_89  2020      1
# 3          28        102         1        86  28102001_86_89  2020      1
# 4          28        102         1        87  28102001_87_89  2020      1
# 5          28        102         1        88  28102001_88_89  2020      1
# 6          28        102         1        89  28102001_89_89  2020      1
# 7          28        120         1        81  28120001_81_89  2020      1
# 8          28        120         1        82  28120001_82_89  2020      1
# 9          28        120         1        83  28120001_83_89  2020      1
# 10         28        120         1        86  28120001_86_89  2020      1
# 11         28        120         1        87  28120001_87_89  2020      1
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228653 entries, 0 to 55536
# Data columns (total 56 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   provincia       228653 non-null  int64
#  1   municipio       228653 non-null  int64
#  2   estacion        228653 non-null  int64
#  3   magnitud        228653 non-null  int64
#  4   punto_muestreo  228653 non-null  object
#  5   year            228653 non-null  int64
#  6   month           228653 non-null  int64
#  7   day             228653 non-null  int64
#  8   h01             228247 non-null  float64
#  9   v01             228653 non-null  object
#  10  h02             228244 non-null  float64
#  11  v02             228653 non-null  object
#  12  h03             228185 non-null  float64
#  13  v03             228653 non-null  object
#  14  h04             228131 non-null  float64
#  15  v04             228653 non-null  object
# ...

# %%
df_total.describe()
# Out:
#        provincia      municipio       estacion       magnitud           year  \
# count   228653.0  228653.000000  228653.000000  228653.000000  228653.000000
# mean        28.0      76.623001      18.552798      50.165036    2020.245372
# std          0.0      39.933976      20.437718      36.778340       0.430308
# min         28.0       5.000000       1.000000       1.000000    2020.000000
# 25%         28.0      65.000000       2.000000      10.000000    2020.000000
# 50%         28.0      79.000000       7.000000      81.000000    2020.000000
# 75%         28.0      79.000000      36.000000      86.000000    2020.000000
# max         28.0     180.000000      60.000000      89.000000    2021.000000
#
#                month            day            h01            h02  \
# count  228653.000000  228653.000000  228247.000000  228244.000000
# mean        6.401416      15.732241      97.037952      95.373743
# std         3.388477       8.805942     242.602083     242.294241
# ...

# %%
estaciones_c = pd.read_csv('../data/estaciones.csv')

# %%
estaciones_c
# Out:
#     CÓDIGO NACIONAL   CÓDIGO MUNICIPIO               NOMBRE ESTACIÓN  \
# 0          28005002                  5             ALCALÁ DE HENARES
# 1          28006004                  6                    ALCOBENDAS
# 2          28007004                  7                      ALCORCÓN
# 3          28009001                  9                        ALGETE
# 4          28013002                 13                      ARANJUEZ
# 5          28014002                 14               ARGANDA DEL REY
# 6          28016001                 16                     EL ATAZAR
# 7          28045002                 45                COLMENAR VIEJO
# 8          28047002                 47              COLLADO VILLALBA
# 9          28049003                 49                       COSLADA
# 10         28058004                 58                   FUENLABRADA
# 11         28065014                 65                        GETAFE
# 12         28067001                 67         GUADALIX DE LA SIERRA
# ...

# %%
df_total['miDt']=pd.to_datetime(df_total[['year','month','day']])

# %%
df_total['miDt'][:2]
# Out:
# 0   2020-01-01
# 1   2020-01-01
# Name: miDt, dtype: datetime64[ns]

# %%
df_total.to_csv('../data/df_total.csv', index=False)

# %%
df_total["estacion"].unique()
# Out:
# array([ 1,  2,  4,  3, 14,  7,  5,  8, 11, 16, 17, 18, 24, 27, 35, 36, 38,
#        39, 40, 47, 48, 49, 50, 54, 55, 56, 57, 58, 59, 60])

# %%
df_total["municipio"].unique()
# Out:
# array([102, 120, 123,  13, 133,  14, 148,  16, 161, 171, 180,  45,  47,
#         49,   5,  58,   6,  65,  67,   7,  74,  80,   9,  92,  79])

# %%
len(df_total["estacion"].unique())
# Out:
# 30

# %%
df_total["magnitud"].unique()
# Out:
# array([81, 82, 83, 86, 87, 88, 89,  1,  6,  7,  8, 12,  9, 10, 14, 20, 30,
#        35, 42, 43, 44])

# %%
df_total["punto_muestreo"].unique()
# Out:
# array(['28102001_81_89', '28102001_82_89', '28102001_83_89',
#        '28102001_86_89', '28102001_87_89', '28102001_88_89',
#        '28102001_89_89', '28120001_81_89', '28120001_82_89',
#        '28120001_83_89', '28120001_86_89', '28120001_87_89',
#        '28120001_88_89', '28120001_89_89', '28123002_81_89',
#        '28123002_82_89', '28123002_83_89', '28123002_86_89',
#        '28123002_87_89', '28123002_88_89', '28123002_89_89',
#        '28013002_81_89', '28013002_82_89', '28013002_83_89',
#        '28013002_86_89', '28013002_87_89', '28013002_88_89',
#        '28013002_89_89', '28133002_81_89', '28133002_82_89',
#        '28133002_83_89', '28133002_86_89', '28133002_87_89',
#        '28133002_88_89', '28133002_89_89', '28014002_81_89',
#        '28014002_82_89', '28014002_83_89', '28014002_86_89',
#        '28014002_87_89', '28014002_88_89', '28014002_89_89',
#        '28148004_81_89', '28148004_82_89', '28148004_83_89',
# ...

# %%
df_total.loc['2020-07-18']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# ...

# %%
df_total[df_total["estacion"]==1 & df_total["magnitud"] == 81]
