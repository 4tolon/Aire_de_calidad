# %% [markdown]
# # Localizar estaciones, coropleticos y demás seres mitologicos

# %%
import pandas as pd
import csv

# %%
est_ay = {
28079035: 'Pza. del Carmen', 
28079004: 'Pza. de España',
28079039: 'Barrio del Pilar', 
28079008: 'Escuelas Aguirre',
28079038: 'Cuatro Caminos', 
28079011: 'Av. Ramón y Cajal',
28079040: 'Vallecas', 
28079016: 'Arturo Soria',
28079017: 'Villaverde',
28079018: 'Farolillo',
28079036: 'Moratalaz', 
28079024: 'Casa de Campo',
28079027: 'Barajas Pueblo',
28079047: 'Méndez Álvaro', 
28079048: 'Castellana', 
28079049: 'Parque del Retiro', 
28079050: 'Plaza Castilla',
28079054: 'Ensanche Vallecas', 
28079055: 'Urb. Embajada',
28079056: 'Pza. Elíptica',
28079057: 'Sanchinarro',
28079058: 'El Pardo', 
28079059: 'Juan Carlos I', 
28079060: 'Tres Olivos'
}

# %%
estaciones_c = pd.read_csv('../data/estaciones.csv')
estaciones_c
# Out:
#     CÓDIGO NACIONAL   CÓDIGO MUNICIPIO               NOMBRE ESTACIÓN  \
# 0          28005002                  5             ALCALÁ DE HENARES
# 1          28006004                  6                    ALCOBENDAS
# 2          28007004                  7                      ALCORCÓN
# 3          28009001                  9                        ALGETE
# 4          28013002                 13                      ARANJUEZ
# 5          28014002                 14               ARGANDA DEL REY
# 6          28016001                 16                     EL ATAZAR
# 7          28045002                 45                COLMENAR VIEJO
# 8          28047002                 47              COLLADO VILLALBA
# 9          28049003                 49                       COSLADA
# 10         28058004                 58                   FUENLABRADA
# 11         28065014                 65                        GETAFE
# 12         28067001                 67         GUADALIX DE LA SIERRA
# ...

# %%
estaciones_c.columns
# Out:
# Index(['CÓDIGO NACIONAL', ' CÓDIGO MUNICIPIO', ' NOMBRE ESTACIÓN',
#        'Unnamed: 3'],
#       dtype='object')

# %%
est_cm = dict(zip(estaciones_c['CÓDIGO NACIONAL'], estaciones_c[' NOMBRE ESTACIÓN']))
est_cm = { k:v.strip() for k, v in est_cm.items()}
est_cm
# Out:
# {28005002: 'ALCALÁ DE HENARES',
#  28006004: 'ALCOBENDAS',
#  28007004: 'ALCORCÓN',
#  28009001: 'ALGETE',
#  28013002: 'ARANJUEZ',
#  28014002: 'ARGANDA DEL REY',
#  28016001: 'EL ATAZAR',
#  28045002: 'COLMENAR VIEJO',
#  28047002: 'COLLADO VILLALBA',
#  28049003: 'COSLADA',
#  28058004: 'FUENLABRADA',
#  28065014: 'GETAFE',
#  28067001: 'GUADALIX DE LA SIERRA',
#  28074007: 'LEGANÉS',
#  28080003: 'MAJADAHONDA',
#  28092005: 'MÓSTOLES',
#  28102001: 'ORUSCO DE TAJUÑA',
#  28120001: 'PUERTO DE COTOS',
#  28123002: 'RIVAS-VACIAMADRID',
#  28133002: 'SAN MARTÍN DE VALDEIGLESIAS',
#  28148004: 'TORREJÓN DE ARDOZ',
#  28161001: 'VALDEMORO',
#  28171001: 'VILLA DEL PRADO',
#  28180001: 'VILLAREJO DE SALVANÉS'}

# %%
est_dic = {**est_ay,**est_cm}

# %%
est_dic
# Out:
# {28079035: 'Pza. del Carmen',
#  28079004: 'Pza. de España',
#  28079039: 'Barrio del Pilar',
#  28079008: 'Escuelas Aguirre',
#  28079038: 'Cuatro Caminos',
#  28079011: 'Av. Ramón y Cajal',
#  28079040: 'Vallecas',
#  28079016: 'Arturo Soria',
#  28079017: 'Villaverde',
#  28079018: 'Farolillo',
#  28079036: 'Moratalaz',
#  28079024: 'Casa de Campo',
#  28079027: 'Barajas Pueblo',
#  28079047: 'Méndez Álvaro',
#  28079048: 'Castellana',
#  28079049: 'Parque del Retiro',
#  28079050: 'Plaza Castilla',
#  28079054: 'Ensanche Vallecas',
#  28079055: 'Urb. Embajada',
#  28079056: 'Pza. Elíptica',
#  28079057: 'Sanchinarro',
#  28079058: 'El Pardo',
#  28079059: 'Juan Carlos I',
#  28079060: 'Tres Olivos',
#  28005002: 'ALCALÁ DE HENARES',
#  28006004: 'ALCOBENDAS',
#  28007004: 'ALCORCÓN',
#  28009001: 'ALGETE',
#  28013002: 'ARANJUEZ',
#  28014002: 'ARGANDA DEL REY',
#  28016001: 'EL ATAZAR',
#  28045002: 'COLMENAR VIEJO',
#  28047002: 'COLLADO VILLALBA',
#  28049003: 'COSLADA',
# ...

# %%
len(est_dic)
# Out:
# 48

# %%
dfff = csv.DictReader('../data/estaciones_cm.csv')

# %%
dfff

# %%
dir(csv)
# Out:
# ['Dialect',
#  'DictReader',
#  'DictWriter',
#  'Error',
#  'QUOTE_ALL',
#  'QUOTE_MINIMAL',
#  'QUOTE_NONE',
#  'QUOTE_NONNUMERIC',
#  'Sniffer',
#  'StringIO',
#  '_Dialect',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'excel',
#  'excel_tab',
#  'field_size_limit',
#  'get_dialect',
#  'list_dialects',
#  're',
#  'reader',
#  'register_dialect',
#  'unix_dialect',
#  'unregister_dialect',
#  'writer']

# %%
dfa = pd.read_excel("../data/excel_am.xlsx")

# %%
dfc = pd.read_excel("../data/excel_cm.xlsx")

# %%
dfa.to_csv('../data/csv_am.csv')

# %%
dfc.to_csv('../data/csv_cm.csv')

# %% [raw]
# dfay= pd.read_csv('../data/csv_am.csv', delimiter=';')
# dfay

# %%
dfco= pd.read_csv('../data/csv_cm.csv', delimiter=';')
dfco
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_4005/2148486787.py in <module>
# ----> 1 dfco= pd.read_csv('../data/csv_cm.csv', delimiter=';')
#       2 dfco
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
estaciones = pd.read_json('../data/estsciones_cm.json')
estaciones
# Out:
#                                                  data
# 0   {'estacion_analizador_CO': 'Si', 'estacion_ana...
# 1   {'estacion_analizador_BEN': 'Si', 'estacion_ti...
# 2   {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 3   {'estacion_tipo_area': 'Suburbana', 'estacion_...
# 4   {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 5   {'estacion_tipo_area': 'Urbana', 'estacion_coo...
# 6   {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 7   {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 8   {'estacion_tipo_area': 'Urbana', 'estacion_coo...
# 9   {'estacion_analizador_BEN': 'Si', 'estacion_ti...
# 10  {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 11  {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 12  {'estacion_analizador_CO': 'Si', 'estacion_tip...
# 13  {'estacion_analizador_PM2_5': 'Si', 'estacion_...
# 14  {'estacion_analizador_CO': 'Si', 'estacion_tip...
# 15  {'estacion_analizador_BEN': 'Si', 'estacion_an...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4005/2387394678.py in <module>
# ----> 1 e = pd.read_json('../data/spacmzoncalidadair_cm_ZONAS.json')
#       2 e
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/miniconda3/envs/minimal_ds/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
